# %%
import socket
import sys
import tkinter as tk
from tkinter import *
from tkinter.filedialog import askopenfile
import cv2
import numpy as np
import struct
window = tk.Tk()
window.geometry("250x200")
window.title("Login")
username_value=tk.StringVar()
password_value=tk.StringVar()
def upload():
    filepath=filedialog.askopenfilename(filetypes=[("image", ".jpeg"),("image", ".png"),("image", ".jpg")])
    print("File location : "+filepath)
    extension = filepath.split('.', 1)
    print("File Type : "+extension[1])
    img=cv2.imread (filepath)
    cv2.imshow('img',img)
    img_encode=cv2.imencode ("."+extension[1], img)[1]
    data_encode=np.array (img_encode)
    data=data_encode.tostring()
    print("Length of Data : "+ str(len(data)))
    print("Encoded Byte Data : ")
    print(img_encode.tobytes())
    #Defining file headers,Packaging into a structure
    
    fhead=struct.pack ("l", len (data))
    
    #Send file header:
    
    clientSock.sendto (fhead, ("127.0.0.1", 20001))
    
    #Cyclic picture stream
    
    for i in range (len (data) //1024 + 1):
        if 1024 * (i + 1)>len (data):
            #checks if any data is left and sends it irrespective of size
            clientSock.sendto (data [1024 * i:], ("127.0.0.1", 20001))
        else:
            #sends data with a size of 1024
            clientSock.sendto (data [1024 * i:1024 * (i + 1)], ("127.0.0.1", 20001))

def submit_login():
    username=username_value.get()
    password=password_value.get()
    if(username=="client" and password=="client"):
        print("You are now logged in")
        window.destroy()
        global clientSock
        clientSock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
        clientSock.sendto("Client connection established".encode(), ("127.0.0.1", 20001))
        print("Connection established, sent message to server")
        upload_file=tk.Tk()
        upload_file.geometry("400x300")
        upload_file.title("Upload an Image")
        tk.Label(upload_file,text="Upload an Image", font="times 15 bold", width=30).grid(row=1,column=1)
        tk.Button(text="Upload an Image",width=20,command=upload).grid(row=2, column=1)
        
    else:
        print("Error")
tk.Label(window,text="Client Login", font="times 15 bold").grid(row=0,column=3)
username=tk.Label(window,text="Username").grid(row=1,column=2,padx=10,pady=10)
password=tk.Label(window,text="Password").grid(row=2,column=2,padx=10)
username_box=tk.Entry(window,textvariable=username_value).grid(row=1,column=3)
password_box=tk.Entry(window,textvariable=password_value,show="*").grid(row=2,column=3)
tk.Button(text="Login",command=submit_login).grid(row=4, column=3,pady=20)
window.mainloop()
# Out:
# You are now logged in
# Connection established, sent message to server
# File location : C:/Users/hanis/Downloads/Hackillinois Selection Mail.jpeg
# File Type : jpeg
# Length of Data : 55922
# Encoded Byte Data :
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x01\xce\x02\x1c\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfd\xfc\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x03?\xfe\x12_\x0e\xee\xfb7\xf6\xe5\x86\xed\xfeW\x97\xf6\xb4\xce\xff\x00\xeec=}\xabB\xbf\x1b\xbf\xe0\x8e\x7f\xf0L\xef\xd8\xf7\xf6\xae\xf8\x9b\xf1\xc3\xf6\x96\xf8\xd9\xf0\xee]W\xc6^\t\xfd\xaau\xf8t\rN\xdf\\\xb9\x828R\xd6X^$\xf2\xd2^\xd5\xf7\x8f\xfc\x14\xb3\xfe\na\xf0\xeb\xfe\t\xd3\xf0\xcbN\xd55O\x0c]\xf8\xaf\xc7\x1e+\xbc\xfb\x0f\x80<\x0b\xa3\x03%\xe6\xb5s\xe8\xbe\xde\xff\x00\xe4\x00}AE~dh_\t\xbf\xe0\xe5\xcf\xda7O?\x12\xfcS\xfbV|3\xf8\x15\x1c\xa3}\xaf\x80\xec|/o\xa9\xcb\x08\xf4\x96\xe6H\xa4\xfc\xaa\r\x1f\xfe\n]\xff\x00\x05\x0f\xff\x00\x82l\xfc]\xd2>\x18\xff\x00\xc1c<\r\xe1\xado\xe1\xf7\x89\xb5\x0f#A\xf8\xe5\xf0\xfe\t!\xb3\xd3\xe4\xc7\x11_\xdb\xe3+\xf5\x1f\xad\x00~\x9fQ_>\xff\x00\xc1E\x7fn\xff\x00\t\xff\x00\xc1?\xbfc/\x11~\xd6Z\xb6\x96\xda\xfcZtQ\xc7\xa2\xe9\xb6]o\xaeg?\xe8\xf1\x83\xef_\x1a\xf8+\xe1\x87\xfc\x1c\xc7\xf1\xc3\xe1\xe5\x9f\xed\n\x9f\xb6\x07\xc3\x1f\x04^j\x16_m\xd3\xfe\x17\\xJ\xdeP\xa0\xfc\xd1\xc5-\xd1\xb6s\x93\xff\x00\xeb\xa0\x0f\xd4\xca+\xe5\xef\xf8%\xcf\xed\x7f\xfbB\xfe\xd6\xbf\x03\xf5K\x9f\xda\xbb\xf6u\xd5~\x1d\xf8\xff\x00\xc2\x1e"\x97B\xf1\r\xb5\xe5\x84\x96\xf6:\x8c\xd1\xff\x00\xcb\xcd\x91\x93\x96B\x0f#\xb1\xc7<\xf1\xf5\r\x00\x14W\xe3g\xecQ\xfbO\x7f\xc1\xc3\xdf\xf0Qo\x86Z\xef\xc6\xaf\xd9\xef\xf6\x88\xf8\x1d\xa4\xf8\x7fH\xf1\xc6\xa1\xa1\x08<Q\xe1\xf6K\x82\xf6\xdeKs\xe5Z\xc8\x07\xdf\xef\xeb\xed_\\~\xc7\xff\x00\x0e\xff\x00\xe0\xbb>\x19\xf8\xe7\xa7j?\xb6\xff\x00\xc7\x8f\x82\x9e#\xf8\x7f\xf69\xfe\xdf\xa7\xf82\xc2\xe6;\xd2\xfcl\xe6K\x18\xf3\xf4\x06\x80>\xdb\xa2\x8ad2\t\x97\xcd\x1d\xe8\x01\xf4W\xc5\t\xfbl|{_\xf8.t\x9f\xb0y\xbd\xd3\x9b ...
# <ipython-input-12-b8983dedd7f4>:23: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   data=data_encode.tostring()
