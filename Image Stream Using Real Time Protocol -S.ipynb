# %%
import socket
import sys
import cv2
import tkinter as tk
import numpy as np
import struct
window = tk.Tk()
window.geometry("250x200")
window.title("Login")
username_value=tk.StringVar()
password_value=tk.StringVar()
def submit_login():
    username=username_value.get()
    password=password_value.get()
    if(username=="admin" and password=="admin"):
        print("You are now logged in")
        window.destroy()
        # Create a datagram socket

        UDPServerSocket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

        # Bind to address and ip

        UDPServerSocket.bind(("127.0.0.1", 20001))

        print("UDP server up and listening")
        
        connection,addr = UDPServerSocket.recvfrom(1024)
        print("\n"+connection.decode())
        # Receive file header,The length of the file header
        count=1
        packet_loss=0
        packet_lpercent=0
        packet_spercent=0
        #receive size and data
        recv_size=0
        data_total=b""
        while True : 
            fhead_size=struct.calcsize ("l")
            buf, addr=UDPServerSocket.recvfrom (fhead_size)
            if buf:
                #returns tuple
                data_size=struct.unpack("l",buf)[0]
               
                
                while not recv_size ==data_size:
                    if data_size - recv_size>1024:
                        data,addr=UDPServerSocket.recvfrom(1024)
                        recv_size+=len(data)
                        print("\nTotal size of message received through buffer till this stream "+str(recv_size)+" (size 1024)")
                        count=count+1
                    else:
                        data,addr=UDPServerSocket.recvfrom(1024)
                        recv_size+=len(data)
                        data_total+=data
                        print("\nTotal size of message received through buffer till this stream "+str(recv_size)+" (size "+str(len(data))+")")
                        print("\nImage received")
                        nparr=np.fromstring (data_total, np.uint8)
                        img_decode=cv2.imdecode (nparr,cv2.IMREAD_COLOR)
                        cv2.imshow('result',img_decode)
                        count=count+1
                    
                break
                
                
        if(recv_size!=data_size):
            packet_loss=data_size-recv_size
        packet_lpercent=(packet_loss//data_size)*100
        packet_spercent=(recv_size//data_size)*100
        print("\nTotal No of messages / packets received: "+str(count))
        print("\nTotal packet/data Loss if any : "+str(packet_loss))
        print("\nPacket/data loss % : "+str(packet_lpercent)+"%")
        print("\nPacket/data success % : "+str(packet_spercent)+"%")
          
                    
    else:
        print("Error")
tk.Label(window,text="Server Login", font="times 15 bold").grid(row=0,column=3)
username=tk.Label(window,text="Username").grid(row=1,column=2,padx=10,pady=10)
password=tk.Label(window,text="Password").grid(row=2,column=2,padx=10)
username_box=tk.Entry(window,textvariable=username_value).grid(row=1,column=3)
password_box=tk.Entry(window,textvariable=password_value,show="*").grid(row=2,column=3)
tk.Button(text="Login",command=submit_login).grid(row=4, column=3,pady=20)
window.mainloop()
# Out:
# You are now logged in
# UDP server up and listening
#
# Client connection established
#
# Total size of message received through buffer till this stream 1024 (size 1024)
#
# Total size of message received through buffer till this stream 2048 (size 1024)
#
# Total size of message received through buffer till this stream 3072 (size 1024)
#
# Total size of message received through buffer till this stream 4096 (size 1024)
#
# Total size of message received through buffer till this stream 5120 (size 1024)
#
# Total size of message received through buffer till this stream 6144 (size 1024)
#
# Total size of message received through buffer till this stream 7168 (size 1024)
#
# Total size of message received through buffer till this stream 8192 (size 1024)
#
# Total size of message received through buffer till this stream 9216 (size 1024)
#
# Total size of message received through buffer till this stream 10240 (size 1024)
#
# Total size of message received through buffer till this stream 11264 (size 1024)
#
# Total size of message received through buffer till this stream 12288 (size 1024)
#
# Total size of message received through buffer till this stream 13312 (size 1024)
#
# Total size of message received through buffer till this stream 14336 (size 1024)
#
# Total size of message received through buffer till this stream 15360 (size 1024)
#
# Total size of message received through buffer till this stream 16384 (size 1024)
#
# Total size of message received through buffer till this stream 17408 (size 1024)
#
# Total size of message received through buffer till this stream 18432 (size 1024)
#
# Total size of message received through buffer till this stream 19456 (size 1024)
#
# Total size of message received through buffer till this stream 20480 (size 1024)
#
# Total size of message received through buffer till this stream 21504 (size 1024)
#
# Total size of message received through buffer till this stream 22528 (size 1024)
#
# Total size of message received through buffer till this stream 23552 (size 1024)
#
# Total size of message received through buffer till this stream 24576 (size 1024)
#
# Total size of message received through buffer till this stream 25600 (size 1024)
#
# Total size of message received through buffer till this stream 26624 (size 1024)
#
# Total size of message received through buffer till this stream 27648 (size 1024)
#
# Total size of message received through buffer till this stream 28672 (size 1024)
#
# Total size of message received through buffer till this stream 29696 (size 1024)
#
# Total size of message received through buffer till this stream 30720 (size 1024)
#
# Total size of message received through buffer till this stream 31744 (size 1024)
#
# Total size of message received through buffer till this stream 32768 (size 1024)
#
# Total size of message received through buffer till this stream 33792 (size 1024)
#
# Total size of message received through buffer till this stream 34816 (size 1024)
#
# Total size of message received through buffer till this stream 35840 (size 1024)
#
# Total size of message received through buffer till this stream 36864 (size 1024)
#
# Total size of message received through buffer till this stream 37888 (size 1024)
#
# Total size of message received through buffer till this stream 38912 (size 1024)
#
# Total size of message received through buffer till this stream 39936 (size 1024)
#
# Total size of message received through buffer till this stream 40960 (size 1024)
#
# Total size of message received through buffer till this stream 41984 (size 1024)
#
# Total size of message received through buffer till this stream 43008 (size 1024)
#
# Total size of message received through buffer till this stream 44032 (size 1024)
#
# Total size of message received through buffer till this stream 45056 (size 1024)
#
# Total size of message received through buffer till this stream 46080 (size 1024)
#
# Total size of message received through buffer till this stream 47104 (size 1024)
#
# Total size of message received through buffer till this stream 48128 (size 1024)
#
# Total size of message received through buffer till this stream 49152 (size 1024)
#
# Total size of message received through buffer till this stream 50176 (size 1024)
#
# Total size of message received through buffer till this stream 51200 (size 1024)
#
# Total size of message received through buffer till this stream 52224 (size 1024)
#
# Total size of message received through buffer till this stream 53248 (size 1024)
#
# Total size of message received through buffer till this stream 54272 (size 1024)
#
# Total size of message received through buffer till this stream 55296 (size 1024)
#
# Total size of message received through buffer till this stream 55922 (size 626)
#
# Image received
# <ipython-input-12-7c9942e6ef32>:58: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   nparr=np.fromstring (data_total, np.uint8)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\hanis\anaconda3\lib\tkinter\__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-12-7c9942e6ef32>", line 60, in submit_login
#     cv2.imshow('result',img_decode)
# cv2.error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-u4kjpz2z\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
